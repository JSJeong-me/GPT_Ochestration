# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GPT_Ochestration/blob/main/Eparse-excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ChrisPappalardo/eparse.git
# Out:
# Cloning into 'eparse'...
# remote: Enumerating objects: 284, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 284 (delta 5), reused 14 (delta 5), pack-reused 266
# Receiving objects: 100% (284/284), 112.96 KiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %%
cd eparse
# Out:
# /content/eparse

# %%
pip install .
# Out:
# Processing /content/eparse
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 88.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 66.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 41.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 42.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 36.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 70.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 72.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for eparse: filename=eparse-0.7.3-py2.py3-none-any.whl size=19230 sha256=a17741318e2f6807924d9a14770b4ad37382945fb306c4dfc20cea1e2e9145d7
# ...

# %%
# !pip install psycopg2-binary

# %%
from eparse.core import get_df_from_file

print([table for table in get_df_from_file('eparse_unit_test_data.xlsx')])

# %%
# %cd ..
# Out:
# /content

# %%
# !eparse -v -f 'eparse_unit_test_data.xlsx' scan
# Out:
# found 1 files
# eparse_unit_test_data.xlsx 0.01MB with 1 sheets

# %%
# !eparse -f 'eparse_unit_test_data.xlsx' -o stdout:/// parse -z
# Out:
# Streaming output truncated to the last 5000 lines.
#  {'c_header': 'Current Valuation:  12/31/2022',
#   'column': 5,
#   'excel_RC': 'I32',
#   'f_name': 'eparse_unit_test_data.xlsx',
#   'name': 'Last Price Discovery:  03/01/2022',
#   'r_header': '40352.66611337962',
#   'row': 6,
#   'sheet': 'TEST',
#   'type': "<class 'float'>",
#   'value': '21759.887338178683'},
#  {'c_header': 'Last Price Discovery:  03/01/2022',
#   'column': 6,
#   'excel_RC': 'J32',
#   'f_name': 'eparse_unit_test_data.xlsx',
#   'name': 'Last Price Discovery:  03/01/2022',
#   'r_header': '40352.66611337962',
#   'row': 6,
#   'sheet': 'TEST',
#   'type': "<class 'float'>",
#   'value': '941058.770786709'},
#  {'c_header': 'Current Valuation:  03/31/2023',
#   'column': 7,
#   'excel_RC': 'K32',
#   'f_name': 'eparse_unit_test_data.xlsx',
#   'name': 'Last Price Discovery:  03/01/2022',
#   'r_header': '40352.66611337962',
#   'row': 6,
#   'sheet': 'TEST',
#   'type': "<class 'float'>",
# ...
